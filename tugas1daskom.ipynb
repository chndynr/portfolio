# %% [markdown]
# <a href="https://colab.research.google.com/github/chndynr/portfolio/blob/main/tugas1daskom.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Tugas Nomor 1 Menampilkan Perintah Menggunakan Print
print ('Nama: Chindy Nujulramdhaniaty')
print ('Alamat: Jl. Bima Blok D No.25 RT 21 RW 04 \n Kelurahan Kuningan \n Kecamatan Kuningan \n Kabupaten Kuningan \n Provinsi Jawa Barat')
print ('Nomor Telepon: 0895338436259')
print ('Pendidikan Terakhir: SMA (IPA)')
# Out:
# Nama: Chindy Nujulramdhaniaty
# Alamat: Jl. Bima Blok D No.25 RT 21 RW 04
#  Kelurahan Kuningan
#  Kecamatan Kuningan
#  Kabupaten Kuningan
#  Provinsi Jawa Barat
# Nomor Telepon: 0895338436259
# Pendidikan Terakhir: SMA (IPA)

# %%
#Tugas Nomor 2 Menampilkan total 5 pembelian barang dengan termasuk pajak
harga_apel = 2000
harga_blueberry = 1000
harga_cherry = 1000
harga_durian = 5000
harga_mangga = 3000

subtotal = apel+blueberry+cherry+durian+mangga
pajak_penjualan = subtotal*0.065
permintaan = 2

print ('jumlah barang yang dibeli:')
print ('apel', harga_apel*permintaan)
print ('blueberry', harga_blueberry*permintaan)
print ('cherry', harga_cherry*permintaan)
print ('durian', harga_durian*permintaan)
print ('mangga', harga_mangga*permintaan)
print ('__________________________')
print ('subtotal:', subtotal*permintaan)
print ('pajak 6,5%:', pajak_penjualan)
print ('total pembayaran:', (subtotal*permintaan)+pajak_penjualan)
# Out:
# jumlah barang yang dibeli:
# apel 4000
# blueberry 2000
# cherry 2000
# durian 10000
# mangga 6000
# __________________________
# subtotal: 24000
# pajak 6,5%: 780.0
# total pembayaran: 24780.0

# %%
#Tugas Nomor 3 Menampilkan Program Menghitung jarak tempuh dari sebuah mobil melaju dengan kecepatan 75 mil/jam

kecepatan = 75
waktu_1 = 6
waktu_2 = 10
waktu_3 = 15

jarak_1 = kecepatan * waktu_1
jarak_2 = kecepatan * waktu_2
jarak_3 = kecepatan * waktu_3

#menampilkan jarak 1
print ('jarak tempuh mobil dalam 6 jam:', jarak_1, 'mil')
#menampilkan jarak 2
print ('jarak tempuh mobil dalam 10 jam:', jarak_2, 'mil')
#menampilkan jarak 3
print ('jarak tempuh mobil dalam 15 jam:', jarak_3, 'mil')
# Out:
# jarak tempuh mobil dalam 6 jam: 450 mil
# jarak tempuh mobil dalam 10 jam: 750 mil
# jarak tempuh mobil dalam 15 jam: 1125 mil

# %%
#Tugas Nomor 4 Program menampilkan berapa banyak kue yang ingin dibuat
#bahan yang telah dikonversi ke gram lalu dibagi dengan 48
gula = int (2500 / 48)
mentega = int (1000 / 48)
tepung = int (2700 / 48)

permintaan = 10

#per 1 kue
print ('[resep pembuatan kue untuk setiap bahan dalam satuan gram]')
print ('permintaan pembeli:', permintaan)
print ('gula:', permintaan*gula, 'gram')
print ('mentega:', permintaan*mentega, 'gram')
print ('tepung:', permintaan*tepung, 'gram')
# Out:
# [resep pembuatan kue untuk setiap bahan dalam satuan gram]
# permintaan pembeli: 10
# gula: 520 gram
# mentega: 200 gram
# tepung: 560 gram
